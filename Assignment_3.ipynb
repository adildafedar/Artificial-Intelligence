# %% [markdown]
# <a href="https://colab.research.google.com/github/adildafedar/Artificial-Intelligence/blob/main/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Sampling is the process of selecting certain pixels from an image.
#When you reduce the sampling rate (i.e., sample fewer pixels), the image becomes lower in resolution.

# %%
"""Quantization reduces the number of intensity (color) levels in an image.
Each pixel's color or intensity is mapped to one of the available quantization levels."""
# Out:
# "Quantization reduces the number of intensity (color) levels in an image.\nEach pixel's color or intensity is mapped to one of the available quantization levels."

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
# Define image file names
image_files = ["sample1.jpg", "sample2.jpg", "sample3.jpg"]

# %%
# Quantization function for RGB images
import numpy as np

def quantize_rgb_image(img_array, levels):
    step = 256 // levels
    return (img_array // step) * step

# %%
sampling_size = (64, 64)
quant_levels = 4

fname = image_files[0]
print(f"📂 Processing: {fname}")

# Load and convert to RGB
img = Image.open(fname).convert("RGB")
img_array = np.array(img)
# Out:
# 📂 Processing: sample1.jpg

# %%
# --- Sampling ---
sampled_img = img.resize(sampling_size, Image.NEAREST)
sampled_array = np.array(sampled_img)

print(f"🔍 Sampled Image Shape: {sampled_array.shape}")
print(f"🔢 Sample Pixel Values (Center 2x2 block):")
center_block = sampled_array[30:32, 30:32]
print(center_block)
# Out:
# 🔍 Sampled Image Shape: (64, 64, 3)
# 🔢 Sample Pixel Values (Center 2x2 block):
# [[[217 181 167]
#   [212 178 166]]
#
#  [[223 186 170]
#   [217 181 165]]]

# %%
# --- Quantization ---
quantized_array = quantize_rgb_image(img_array, quant_levels)

# Analyze unique levels
red_unique = np.unique(quantized_array[..., 0])
green_unique = np.unique(quantized_array[..., 1])
blue_unique = np.unique(quantized_array[..., 2])

print(f"🎨 Unique Quantized Levels:")
print(f"  🔴 Red: {red_unique}")
print(f"  🟢 Green: {green_unique}")
print(f"  🔵 Blue: {blue_unique}")
# Out:
# 🎨 Unique Quantized Levels:
#   🔴 Red: [  0  64 128 192]
#   🟢 Green: [  0  64 128 192]
#   🔵 Blue: [  0  64 128 192]

# %%
# --- Visualization ---
plt.figure(figsize=(15, 4))

plt.subplot(1, 3, 1)
plt.imshow(img)
plt.title("Original Image")
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(sampled_array)
plt.title("Sampled (64x64)")
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(quantized_array)
plt.title("Quantized (4 Levels)")
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
fname = image_files[1]
print(f"📂 Processing: {fname}")

# Load and convert to RGB
img = Image.open(fname).convert("RGB")
img_array = np.array(img)
# Out:
# 📂 Processing: sample2.jpg

# %%
# --- Sampling ---
sampled_img = img.resize(sampling_size, Image.NEAREST)
sampled_array = np.array(sampled_img)

print(f"🔍 Sampled Image Shape: {sampled_array.shape}")
print(f"🔢 Sample Pixel Values (Center 5x5 block):")
center_block = sampled_array[30:35, 30:35]
print(center_block)
# Out:
# 🔍 Sampled Image Shape: (64, 64, 3)
# 🔢 Sample Pixel Values (Center 5x5 block):
# [[[250 225 218]
#   [254 207 189]
#   [250 208 196]
#   [243 206 190]
#   [245 207 188]]
#
#  [[246 216 205]
#   [244 216 204]
#   [253 217 205]
#   [247 218 202]
#   [248 206 192]]
#
#  [[243 215 204]
#   [249 215 206]
#   [250 217 212]
#   [252 203 189]
#   [232 170 149]]
#
#  [[251 221 213]
#   [247 210 204]
#   [236 189 179]
#   [238 181 164]
#   [245 177 154]]
#
#  [[247 207 195]
#   [238 186 173]
#   [249 192 175]
#   [232 166 144]
#   [234 159 136]]]

# %%
# --- Quantization ---
quant_levels = 8
quantized_array = quantize_rgb_image(img_array, quant_levels)

# Analyze unique levels
red_unique = np.unique(quantized_array[..., 0])
green_unique = np.unique(quantized_array[..., 1])
blue_unique = np.unique(quantized_array[..., 2])

print(f"🎨 Unique Quantized Levels:")
print(f"  🔴 Red: {red_unique}")
print(f"  🟢 Green: {green_unique}")
print(f"  🔵 Blue: {blue_unique}")
# Out:
# 🎨 Unique Quantized Levels:
#   🔴 Red: [  0  32  64  96 128 160 192 224]
#   🟢 Green: [  0  32  64  96 128 160 192 224]
#   🔵 Blue: [  0  32  64  96 128 160 192 224]

# %%
# --- Visualization ---
plt.figure(figsize=(15, 4))

plt.subplot(1, 3, 1)
plt.imshow(img)
plt.title("Original Image")
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(sampled_array)
plt.title("Sampled (64x64)")
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(quantized_array)
plt.title("Quantized (8 Levels)")
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
fname = image_files[2]
print(f"📂 Processing: {fname}")

# Load and convert to RGB
img = Image.open(fname).convert("RGB")
img_array = np.array(img)
# Out:
# 📂 Processing: sample3.jpg

# %%
# --- Sampling ---
sampled_img = img.resize(sampling_size, Image.NEAREST)
sampled_array = np.array(sampled_img)

print(f"🔍 Sampled Image Shape: {sampled_array.shape}")
print(f"🔢 Sample Pixel Values (Center 7x7 block):")
center_block = sampled_array[30:36, 30:36]
print(center_block)
# Out:
# 🔍 Sampled Image Shape: (64, 64, 3)
# 🔢 Sample Pixel Values (Center 7x7 block):
# [[[105 108 113]
#   [133 133 135]
#   [120 129 128]
#   [150 151 153]
#   [183 170 177]
#   [189 183 187]]
#
#  [[104 110 110]
#   [122 129 135]
#   [132 131 137]
#   [215 206 211]
#   [222 210 214]
#   [208 192 195]]
#
#  [[ 86  92  92]
#   [168 167 165]
#   [212 206 206]
#   [232 221 219]
#   [218 207 205]
#   [212 197 200]]
#
#  [[111 117 117]
#   [111 109 110]
#   [171 167 166]
#   [180 176 173]
#   [168 165 160]
#   [200 190 191]]
#
#  [[125 131 131]
#   [125 128 133]
#   [126 129 134]
#   [136 141 144]
#   [187 193 193]
#   [148 142 144]]
#
#  [[147 147 149]
#   [131 129 132]
#   [145 146 150]
#   [128 131 138]
#   [114 119 125]
#   [133 134 138]]]

# %%
# --- Quantization ---
quant_levels = 16
quantized_array = quantize_rgb_image(img_array, quant_levels)

# Analyze unique levels
red_unique = np.unique(quantized_array[..., 0])
green_unique = np.unique(quantized_array[..., 1])
blue_unique = np.unique(quantized_array[..., 2])

print(f"🎨 Unique Quantized Levels:")
print(f"  🔴 Red: {red_unique}")
print(f"  🟢 Green: {green_unique}")
print(f"  🔵 Blue: {blue_unique}")
# Out:
# 🎨 Unique Quantized Levels:
#   🔴 Red: [  0  16  32  48  64  80  96 112 128 144 160 176 192 208 224 240]
#   🟢 Green: [  0  16  32  48  64  80  96 112 128 144 160 176 192 208 224 240]
#   🔵 Blue: [  0  16  32  48  64  80  96 112 128 144 160 176 192 208 224 240]

# %%
# --- Visualization ---
plt.figure(figsize=(15, 4))

plt.subplot(1, 3, 1)
plt.imshow(img)
plt.title("Original Image")
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(sampled_array)
plt.title("Sampled (64x64)")
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(quantized_array)
plt.title("Quantized (16 Levels)")
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# *The experiments demonstrate the fundamental impacts of sampling and quantization on digital images. Downsampling effectively lowers spatial resolution while quantization limits color precision. Optimizing the parameters for these processes involves balancing compression and performance goals against the desired visual quality.*
